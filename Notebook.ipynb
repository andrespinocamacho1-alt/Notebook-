# %% [markdown]
# <a href="https://colab.research.google.com/github/andrespinocamacho1-alt/Notebook-/blob/main/Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***CONTENIDOS***
#
# 1. **Introduccion**
# 2. Objetivos
# 3. Marco Teorico
# 4. Analisis De Resultados
# 5. Apuntes de LaTeX

# %% [markdown]
# #APUNTES DE LaTeX
#
# EL PDF APUNTES DE LATEX ENSEÑA A ESCRIBIR ECUACIONES Y FORMULAS MATEMATICAS EN FORMATO LATE. EL SIGUIENTE LINK PERMITE DESCARGAR EL PDF:
#
# [APUNTES DE LaTeX](https://metodos.fam.cie.uva.es/~latex/apuntes/apuntes3.pdf)

# %% [markdown]
# #ECUACIONES
